# %%
from scipy.interpolate import interp1d

# %%
import numpy as np

# %%
x=np.linspace(0,10,num=11,endpoint=True)

# %%
y=np.cos(-x**2/9.)

# %%
f=interp1d(x,y) #linear approximation

# %%
f2=interp1d(x,y,kind='cubic') #cubic spline interpolation

# %%
xnew=np.linspace(0,10,num=41,endpoint=True)
ynew=np.cos(-xnew**2/9.)
xref=np.linspace(0,10,num=41,endpoint=True)
yref=np.cos(-xref**2/9.)
xdense=np.linspace(0,10,num=400,endpoint=True)
ydense=np.cos(-xdense**2/9.)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y,'o',xnew,f(xnew),'-',xnew,f2(xnew),'--',xref,ynew,'k.',xdense,ydense)
plt.legend(['data','linear','cubic'],loc=2)

# %%
plt.show()
