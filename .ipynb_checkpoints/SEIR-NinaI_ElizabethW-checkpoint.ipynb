# %%
#https://towardsdatascience.com/social-distancing-to-slow-the-coronavirus-768292f04296
import numpy as np
import matplotlib.pyplot as plt
def base_seir_model(init_vals, params, t):
    S_0, E_0, I_0, R_0 = init_vals
    S, E, I, R = [S_0], [E_0], [I_0], [R_0]
    alpha, beta, gamma = params
    dt = t[1] - t[0]
    for _ in t[1:]:
        next_S = S[-1] - (beta*S[-1]*I[-1])*dt
        next_E = E[-1] + (beta*S[-1]*I[-1] - alpha*E[-1])*dt
        next_I = I[-1] + (alpha*E[-1] - gamma*I[-1])*dt
        next_R = R[-1] + (gamma*I[-1])*dt
        S.append(next_S)
        E.append(next_E)
        I.append(next_I)
        R.append(next_R)
    return np.stack([S, E, I, R]).T

# %%
# Define parameters
t_max = 100
dt = .1
t1 = np.linspace(0, t_max, int(t_max/dt) + 1)
N = 10000
init_vals = 1 - 1/N, 1/N, 0, 0
alpha = 0.2
beta = 1.75
gamma = 0.5
params = alpha, beta, gamma
# Run simulation
results1 = base_seir_model(init_vals, params, t1)

# %%
plt.plot(t1,results1[:,2])
plt.xlim(0,100)
# Out:
# (0, 100)

# %%
def seir_model_with_soc_dist(init_vals, params, t):
    S_0, E_0, I_0, R_0 = init_vals
    S, E, I, R = [S_0], [E_0], [I_0], [R_0]
    alpha, beta, gamma, rho = params
    dt = t[1] - t[0]
    for _ in t[1:]:
        next_S = S[-1] - (rho*beta*S[-1]*I[-1])*dt
        next_E = E[-1] + (rho*beta*S[-1]*I[-1] - alpha*E[-1])*dt
        next_I = I[-1] + (alpha*E[-1] - gamma*I[-1])*dt
        next_R = R[-1] + (gamma*I[-1])*dt
        S.append(next_S)
        E.append(next_E)
        I.append(next_I)
        R.append(next_R)
    return np.stack([S, E, I, R]).T

# %%
# Define parameters
t_max = 500
dt = .1
t2 = np.linspace(0, t_max, int(t_max/dt) + 1)
N = 10000
init_vals = 1 - 1/N, 1/N, 0, 0
alpha = 0.2
beta = 1.75
gamma = 0.5
rho=.5
params = alpha, beta, gamma,rho
# Run simulation
results2 = seir_model_with_soc_dist(init_vals, params, t2)

# %%
plt.plot(t2,results2[:,2])
plt.xlim(0,500)
# Out:
# (0, 500)

# %%
#plotting no distancing and distancing on the same figure to compare the two
plt.plot(t1,results1[:,2],label="No Social Distancing")
plt.plot(t2,results2[:,2],label="With Social Distancing")
plt.legend()
plt.ylabel("Percent of Population Infected")
plt.xlabel("Days")
plt.title("COVID-19 Model")
plt.xlim(0,300)
plt.show()

# %%
#changing rho to reflect that people might stay inside more during colder seasons
#and outside more during warmer seasons
# Define parameters
t_max = 500
dt = .1
t2 = np.linspace(0, t_max, int(t_max/dt) + 1)
N = 10000
init_vals = 1 - 1/N, 1/N, 0, 0
alpha = 0.2
beta = 1.75
gamma = 0.5
rho=.75 #three quarters of population are not quarentined. 
params = alpha, beta, gamma,rho
# Run simulation
results3 = seir_model_with_soc_dist(init_vals, params, t2)
plt.plot(t2,results3[:,2])
plt.xlim(0,500)
# Out:
# (0, 500)

# %%
#changing rho to reflect that people might stay inside more during colder seasons
#and outside more during warmer seasons
# Define parameters
t_max = 500
dt = .1
t2 = np.linspace(0, t_max, int(t_max/dt) + 1)
N = 10000
init_vals = 1 - 1/N, 1/N, 0, 0
alpha = 0.2
beta = 1.75
gamma = 0.5
rho=0.85 #three quarters of population are not quarentined. 
params = alpha, beta, gamma,rho
# Run simulation
results4 = seir_model_with_soc_dist(init_vals, params, t2)
plt.plot(t2,results4[:,2])
plt.xlim(0,500)
# Out:
# (0, 500)

# %%
#plotting no distancing and distancing on the same figure to compare the two
plt.plot(t1,results1[:,2],label="No Social Distancing")
plt.plot(t2,results2[:,2],label="With 0.5 Social Distancing")
plt.plot(t2,results3[:,2],label="With 1/4 of the population SD")
plt.plot(t2,results4[:,2],label="85% of pop not SD")
plt.legend()
plt.ylabel("Percent of Population Infected")
plt.xlabel("Days")
plt.title("COVID-19 Model")
plt.xlim(0,175)
plt.show()

# %%
#can we change alpha to make it a time dependent term? Would that reflect seasonal variations?
#lets plot the same plot with different alphas
# Define parameters

#alpha=0.2
t_max = 500
dt = .1
t2 = np.linspace(0, t_max, int(t_max/dt) + 1)
N = 10000
init_vals = 1 - 1/N, 1/N, 0, 0
alpha = 0.2
beta = 1.75
gamma = 0.5
rho=.5
params = alpha, beta, gamma,rho
# Run simulation
results2 = seir_model_with_soc_dist(init_vals, params, t2)

#alpha=0.1
t_max = 500
dt = .1
t2 = np.linspace(0, t_max, int(t_max/dt) + 1)
N = 10000
init_vals = 1 - 1/N, 1/N, 0, 0
alpha = 0.1 #double the incubation period
beta = 1.75
gamma = 0.5
rho=.5
params = alpha, beta, gamma,rho
# Run simulation
results5 = seir_model_with_soc_dist(init_vals, params, t2)

#alpha=0.5
t_max = 500
dt = .1
t2 = np.linspace(0, t_max, int(t_max/dt) + 1)
N = 10000
init_vals = 1 - 1/N, 1/N, 0, 0
alpha = 0.5 
beta = 1.75
gamma = 0.5
rho=.5
params = alpha, beta, gamma,rho
# Run simulation
results6 = seir_model_with_soc_dist(init_vals, params, t2)



plt.plot(t2,results2[:,2],label="5 day incubation period")
plt.plot(t2,results5[:,2],label="10 day incubation period")
plt.plot(t2,results6[:,2],label="2 day incubation period")
plt.ylabel("Percent of Population Infected")
plt.xlabel("Days")
plt.title("COVID-19 Model")
plt.xlim(0,400)
plt.legend()
plt.show()

print("We think that the area under the curves are probably the same. Thus the figure we are seeing represents that a larger percent of the population are infected sooner.")
# Out:
# We think that the area under the curves are probably the same. Thus the figure we are seeing represents that a larger percent of the population are infected sooner.
